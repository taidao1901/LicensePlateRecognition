# %% [markdown]
# # COPY DATA

# %%
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt

# %%
def copy_all(path_copy_from, path_copy_to):
    lst_file = os.listdir(path_copy_from)
    for f in lst_file:
        f_from = os.path.join(path_copy_from, f)
        f_to = os.path.join(path_copy_to, f)
        shutil.copy(f_from, f_to)
        print(f"Copy {f}")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# copy_all('/content/drive/MyDrive/CS331_Nhóm/Datasets_Recog/Image/Train', '/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/Data_Aug_Recog/Images')
# copy_all('/content/drive/MyDrive/CS331_Nhóm/Datasets_Recog/Label/Train', '/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/Data_Aug_Recog/Labels')
# copy_all('/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_recog_rename/images', '/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/Data_Aug_Recog/Images')
# copy_all('/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_recog_rename/label', '/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/Data_Aug_Recog/Labels')
# Out:
# Streaming output truncated to the last 5000 lines.
# Copy 2402.jpg
# Copy 2315.jpg
# Copy 2311.jpg
# Copy 2359.jpg
# Copy 2412.jpg
# Copy 2292.jpg
# Copy 2400.jpg
# Copy 2389.jpg
# Copy 2387.jpg
# Copy 2331.jpg
# Copy 2351.jpg
# Copy 2373.jpg
# Copy 2291.jpg
# Copy 2361.jpg
# Copy 2372.jpg
# Copy 2330.jpg
# Copy 2396.jpg
# Copy 2301.jpg
# Copy 2344.jpg
# Copy 2314.jpg
# Copy 2325.jpg
# Copy 2408.jpg
# Copy 2362.jpg
# Copy 2334.jpg
# Copy 2399.jpg
# Copy 2318.jpg
# Copy 2395.jpg
# Copy 2347.jpg
# Copy 2300.jpg
# Copy 2413.jpg
# Copy 2356.jpg
# Copy 2313.jpg
# Copy 2333.jpg
# Copy 2369.jpg
# Copy 2339.jpg
# Copy 2405.jpg
# Copy 2381.jpg
# Copy 2324.jpg
# Copy 2329.jpg
# Copy 2304.jpg
# Copy 2384.jpg
# Copy 2321.jpg
# Copy 2303.jpg
# Copy 2368.jpg
# Copy 2294.jpg
# Copy 2320.jpg
# Copy 2352.jpg
# Copy 2350.jpg
# Copy 2336.jpg
# Copy 2326.jpg
# Copy 2335.jpg
# Copy 2308.jpg
# Copy 2394.jpg
# Copy 2382.jpg
# Copy 2338.jpg
# Copy 2306.jpg
# Copy 2398.jpg
# Copy 2380.jpg
# Copy 2305.jpg
# ...

# %%
print(len(os.listdir('/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/Data_Aug_Recog/Images')))
print(len(os.listdir('/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/Data_Aug_Recog/Labels')))
# Out:
# 5240
# 5240

# %% [markdown]
# # DarkNet

# %%
# %cd /content/drive/MyDrive/Test_CRNet
# Out:
# /content/drive/MyDrive/Test_CRNet

# %%
# !rm -rf darknet
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15424, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 15424 (delta 0), reused 1 (delta 0), pack-reused 15423
# Receiving objects: 100% (15424/15424), 14.05 MiB | 8.18 MiB/s, done.
# Resolving deltas: 100% (10364/10364), done.
# Checking out files: 100% (2050/2050), done.

# %%
# %cd ./darknet/
# Out:
# /content/drive/MyDrive/Test_CRNet/darknet

# %%
# !mkdir backup

# %%
import os
import shutil

# %%
# Copy data
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Test_CRNet/darknet

# %%
# %cd ./data
# Out:
# /content/drive/MyDrive/Test_CRNet/darknet/data

# %%
# !ls
# Out:
# 9k.tree     eagle.jpg	 imagenet.labels.list	   person.jpg
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  scream.jpg
# coco.names  goal.txt	 labels			   voc.names
# dog.jpg     horses.jpg	 openimages.names

# %%
# !mkdir train
# !mkdir valid
# !mkdir test

# %%
copy_all('/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/Data_Aug_Recog/Images', '/content/drive/MyDrive/Test_CRNet/darknet/data/train')
copy_all('/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/Data_Aug_Recog/Labels', '/content/drive/MyDrive/Test_CRNet/darknet/data/train')
copy_all('/content/drive/MyDrive/CS331_Nhóm/Datasets_Recog/Image/Test/', '/content/drive/MyDrive/Test_CRNet/darknet/data/test')
copy_all('/content/drive/MyDrive/CS331_Nhóm/Datasets_Recog/Label/Test/', '/content/drive/MyDrive/Test_CRNet/darknet/data/test')
copy_all('/content/drive/MyDrive/CS331_Nhóm/Datasets_Recog/Image/Validation/', '/content/drive/MyDrive/Test_CRNet/darknet/data/valid')
copy_all('/content/drive/MyDrive/CS331_Nhóm/Datasets_Recog/Label/Validation/', '/content/drive/MyDrive/Test_CRNet/darknet/data/valid')
# Out:
# Streaming output truncated to the last 5000 lines.
# Copy 3712.txt
# Copy 3767.txt
# Copy 3719.txt
# Copy 3705.txt
# Copy 3765.txt
# Copy 3654.txt
# Copy 3835.txt
# Copy 3842.txt
# Copy 3821.txt
# Copy 3839.txt
# Copy 3847.txt
# Copy 3837.txt
# Copy 3825.txt
# Copy 3831.txt
# Copy 3877.txt
# Copy 3801.txt
# Copy 3798.txt
# Copy 3862.txt
# Copy 3812.txt
# Copy 3865.txt
# Copy 3816.txt
# Copy 3868.txt
# Copy 3848.txt
# Copy 3866.txt
# Copy 3828.txt
# Copy 3885.txt
# Copy 3784.txt
# Copy 3807.txt
# Copy 3876.txt
# Copy 3857.txt
# Copy 3863.txt
# Copy 3871.txt
# Copy 3836.txt
# Copy 3832.txt
# Copy 3850.txt
# Copy 3882.txt
# Copy 3809.txt
# Copy 3884.txt
# Copy 3838.txt
# Copy 3823.txt
# Copy 3788.txt
# Copy 3887.txt
# Copy 3780.txt
# Copy 3819.txt
# Copy 3786.txt
# Copy 3813.txt
# Copy 3797.txt
# Copy 3889.txt
# Copy 3789.txt
# Copy 3856.txt
# Copy 3791.txt
# Copy 3794.txt
# Copy 3795.txt
# Copy 3782.txt
# Copy 3867.txt
# Copy 3800.txt
# Copy 3781.txt
# Copy 3854.txt
# Copy 3827.txt
# ...

# %%
len(os.listdir('/content/drive/MyDrive/Test_CRNet/darknet/data/train/'))
# Out:
# 10480

# %%
# %cd /content/drive/MyDrive/Test_CRNet/darknet
# !echo "0" > yolo.names
# !echo "1" >> yolo.names
# !echo "2" >> yolo.names
# !echo "3" >> yolo.names
# !echo "4" >> yolo.names
# !echo "5" >> yolo.names
# !echo "6" >> yolo.names
# !echo "7" >> yolo.names
# !echo "8" >> yolo.names
# !echo "9" >> yolo.names
# !echo "A" >> yolo.names
# !echo "B" >> yolo.names
# !echo "C" >> yolo.names
# !echo "D" >> yolo.names
# !echo "E" >> yolo.names
# !echo "F" >> yolo.names
# !echo "G" >> yolo.names
# !echo "H" >> yolo.names
# !echo "K" >> yolo.names
# !echo "L" >> yolo.names
# !echo "M" >> yolo.names
# !echo "N" >> yolo.names
# !echo "P" >> yolo.names
# !echo "S" >> yolo.names
# !echo "T" >> yolo.names
# !echo "U" >> yolo.names
# !echo "V" >> yolo.names
# !echo "X" >> yolo.names
# !echo "Y" >> yolo.names
# !echo "Z" >> yolo.names
# !echo "R" >> yolo.names
# Out:
# /content/drive/MyDrive/Test_CRNet/darknet

# %%
import glob2

# %%
# %cd /content/drive/MyDrive/Test_CRNet/darknet/data/train
path = "/content/drive/MyDrive/Test_CRNet/darknet/data/train"

types = ('*.jpg', '*.png', '*.jpeg')
# path_txt = glob2.glob("*.txt")
path_img = list()
for type_ in types:
  path_img.extend(glob2.glob(type_))

with open("/content/drive/MyDrive/Test_CRNet/darknet/train.txt","w") as f:
  for img in path_img:
    image_files = os.path.join(path, img)
    print(image_files)
    #tìm kiếm các file có đuôi dạng: png, jpeg, jpg trong thư mục
    if (os.path.exists(str(image_files[:-3]) + "txt")) or (os.path.exists(str(image_files[:-4]) + "txt")):
      f.write(image_files+'\n')
    #lưu tất cả các file vào biến files
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/Test_CRNet/darknet/data/train/2350.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/train/2336.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/train/2326.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/train/2335.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/train/2308.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/train/2394.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/train/2382.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/train/2338.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/train/2306.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/train/2398.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/train/2380.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/train/2305.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/train/2323.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/train/2370.jpg
# ...

# %%
# %cd /content/drive/MyDrive/Test_CRNet/darknet/data/valid
path = "/content/drive/MyDrive/Test_CRNet/darknet/data/valid"

types = ('*.jpg', '*.png', '*.jpeg')
# path_txt = glob2.glob("*.txt")
path_img = list()
for type_ in types:
  path_img.extend(glob2.glob(type_))

with open("/content/drive/MyDrive/Test_CRNet/darknet/valid.txt","w") as f:
  for img in path_img:
    image_files = os.path.join(path, img)
    print(image_files)
    #tìm kiếm các file có đuôi dạng: png, jpeg, jpg trong thư mục
    if (os.path.exists(str(image_files[:-3]) + "txt")) or (os.path.exists(str(image_files[:-4]) + "txt")):
      f.write(image_files+'\n')
    #lưu tất cả các file vào biến files
# Out:
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid/1268.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid/264.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid/1713.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid/1196.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid/1470.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid/1047.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid/1284.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid/276.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid/1140.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid/1573.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid/726.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid/236.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid/1097.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/valid/621.jpg
# ...

# %%
# %cd /content/drive/MyDrive/Test_CRNet/darknet/data/test
path = "/content/drive/MyDrive/Test_CRNet/darknet/data/test"

types = ('*.jpg', '*.png', '*.jpeg')
# path_txt = glob2.glob("*.txt")
path_img = list()
for type_ in types:
  path_img.extend(glob2.glob(type_))

with open("/content/drive/MyDrive/Test_CRNet/darknet/test.txt","w") as f:
  for img in path_img:
    image_files = os.path.join(path, img)
    print(image_files)
    #tìm kiếm các file có đuôi dạng: png, jpeg, jpg trong thư mục
    if (os.path.exists(str(image_files[:-3]) + "txt")) or (os.path.exists(str(image_files[:-4]) + "txt")):
      f.write(image_files+'\n')
    #lưu tất cả các file vào biến files
# Out:
# /content/drive/MyDrive/Test_CRNet/darknet/data/test
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/1205.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/372.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/257.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/982.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/1610.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/268.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/510.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/997.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/182.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/1181.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/923.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/808.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/864.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/6.jpg
# /content/drive/MyDrive/Test_CRNet/darknet/data/test/1221.jpg
# ...

# %%
# %cd /content/drive/MyDrive/Test_CRNet/darknet
#!mkdir backup
# !echo classes=31 > yolo.data
# !echo train=train.txt >> yolo.data
# !echo valid=valid.txt >> yolo.data
# !echo names=yolo.names >> yolo.data
# !echo backup=backup >> yolo.data
# Out:
# /content/drive/.shortcut-targets-by-id/1U9-WSyvgsdjZvpOeMVG-Uxo2Fm-E65iF/Test_CRNet/darknet

# %% [markdown]
# # Pre-training

# %%
# %cd /content/drive/MyDrive/Test_CRNet/darknet
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/g' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/g' Makefile
# Out:
# /content/drive/.shortcut-targets-by-id/1U9-WSyvgsdjZvpOeMVG-Uxo2Fm-E65iF/Test_CRNet/darknet

# %%
# %cd /content/drive/MyDrive/Test_CRNet/darknet
# Out:
# /content/drive/MyDrive/Test_CRNet/darknet

# %% [markdown]
# # Training

# %%
# %cd /content/drive/MyDrive/Test_CRNet/darknet
# !rm darknet
# !make
# Out:
# /content/drive/.shortcut-targets-by-id/1U9-WSyvgsdjZvpOeMVG-Uxo2Fm-E65iF/Test_CRNet/darknet
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ...

# %%
# %cd /content/drive/MyDrive/Test_CRNet/darknet
# !./darknet detector train yolo.data cfg/cr-net.cfg -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
# Region Avg IOU: 0.845116, Class: 0.984319, Obj: 0.774150, No Obj: 0.010817, Avg Recall: 1.000000,  count: 66
# Region Avg IOU: 0.853611, Class: 0.990289, Obj: 0.781317, No Obj: 0.012533, Avg Recall: 1.000000,  count: 69
#
#  (next mAP calculation at 14407 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.50 = 99.71 %, best = 99.93 %
#  14286: 0.578998, 0.771545 avg loss, 0.001000 rate, 0.449799 seconds, 914304 images, 1.006849 hours left
# Loaded: 0.000039 seconds
# Region Avg IOU: 0.834444, Class: 0.983941, Obj: 0.820015, No Obj: 0.014201, Avg Recall: 0.986111,  count: 72
# Region Avg IOU: 0.860240, Class: 0.991750, Obj: 0.817994, No Obj: 0.015165, Avg Recall: 1.000000,  count: 70
# Region Avg IOU: 0.855419, Class: 0.986472, Obj: 0.787299, No Obj: 0.016146, Avg Recall: 1.000000,  count: 67
# Region Avg IOU: 0.837080, Class: 0.981064, Obj: 0.803704, No Obj: 0.013709, Avg Recall: 1.000000,  count: 67
# ...

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
# %cd /content/drive/MyDrive/Test_CRNet/darknet
# Out:
# /content/drive/.shortcut-targets-by-id/1U9-WSyvgsdjZvpOeMVG-Uxo2Fm-E65iF/Test_CRNet/darknet

# %%
# !./darknet detector test "/content/drive/MyDrive/Test_CRNet/darknet/yolo.data" "/content/drive/MyDrive/Test_CRNet/darknet/cfg/cr-net.cfg" "/content/drive/MyDrive/Test_CRNet/darknet/backup/cr-net_best.weights" "/content/drive/MyDrive/Test_CRNet/darknet/data/test/1570.jpg"
# Out:
# CUDA status Error: file: ./src/dark_cuda.c : () : line: 38 : build time: Jun 15 2022 - 03:58:01
#
#  CUDA Error: no CUDA-capable device is detected
# Darknet error location: ./src/dark_cuda.c, check_error, line #69
# CUDA Error: no CUDA-capable device is detected: Bad file descriptor

# %%
imShow('predictions.jpg')

# %%
# !./darknet detector test yolo.data cfg/cr-net.cfg backup/cr-net_best.weights -dont_show -ext_output < test.txt > result.txt
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    352 x 128 x   3 ->  352 x 128 x  32 0.078 BF
#    1 max                2x 2/ 2    352 x 128 x  32 ->  176 x  64 x  32 0.001 BF
#    2 conv     64       3 x 3/ 1    176 x  64 x  32 ->  176 x  64 x  64 0.415 BF
#    3 max                2x 2/ 2    176 x  64 x  64 ->   88 x  32 x  64 0.001 BF
#    4 conv    128       3 x 3/ 1     88 x  32 x  64 ->   88 x  32 x 128 0.415 BF
#    5 conv     64       1 x 1/ 1     88 x  32 x 128 ->   88 x  32 x  64 0.046 BF
#    6 conv    128       3 x 3/ 1     88 x  32 x  64 ->   88 x  32 x 128 0.415 BF
#    7 max                2x 2/ 2     88 x  32 x 128 ->   44 x  16 x 128 0.000 BF
#    8 conv    256       3 x 3/ 1     44 x  16 x 128 ->   44 x  16 x 256 0.415 BF
# ...

# %%
# !./darknet detector map yolo.data cfg/cr-net.cfg backup/cr-net_best.weights
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    352 x 128 x   3 ->  352 x 128 x  32 0.078 BF
#    1 max                2x 2/ 2    352 x 128 x  32 ->  176 x  64 x  32 0.001 BF
#    2 conv     64       3 x 3/ 1    176 x  64 x  32 ->  176 x  64 x  64 0.415 BF
#    3 max                2x 2/ 2    176 x  64 x  64 ->   88 x  32 x  64 0.001 BF
#    4 conv    128       3 x 3/ 1     88 x  32 x  64 ->   88 x  32 x 128 0.415 BF
#    5 conv     64       1 x 1/ 1     88 x  32 x 128 ->   88 x  32 x  64 0.046 BF
#    6 conv    128       3 x 3/ 1     88 x  32 x  64 ->   88 x  32 x 128 0.415 BF
# ...
