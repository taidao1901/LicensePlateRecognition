# %%
# !unzip '/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_detect.zip' -d '/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_detect/700_2_1026.txt
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_detect/42_1_1172.txt
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_detect/634_2_1705.jpg
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_detect/683_0_1335.jpg
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_detect/513_1_1142.jpg
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_detect/66_1_1420.txt
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_detect/378_0_723.jpg
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_detect/265_0_1447.jpg
# ...

# %%
import os
a = os.listdir('/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_recog')

# %%
arr = []
for x in a:
  if x[-4:] == '.txt':
    arr.append(x.split('.')[0])

# %%
len(arr)
# Out:
# 4192

# %%
def get_name(path_name, txt = True):
  arr_name=[]
  for x in path_name:
    if txt:
      tmp = x.split('.')[0] + '.txt'
    else:
      tmp = x.split('.')[0] + '.jpg'
    arr_name.append(tmp)
  return arr_name

# %%
labels_train = get_name(arr)

# %%
images_train = get_name(arr, txt=False)

# %%
import shutil

# %%
path_aug_detect = '/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_recog'

# %%
def Copy_Img(path):
  for i in path:
    src_path = os.path.join(path_aug_detect,i)
    dst_path = os.path.join('/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/Augmented_Recog/Image')
    shutil.copy(src_path, dst_path)
    print('Image {}: {}'.format(dir,i))

# %%
def Copy_Lb(path):
  for i in path:
    src_path = os.path.join(path_aug_detect,i)
    dst_path = os.path.join('/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/Augmented_Recog/Label')
    shutil.copy(src_path, dst_path)
    print('Label {}: {}'.format(dir,i))

# %%
Copy_Img(images_train)
# Out:
# Image <built-in function dir>: 859_3_1584.jpg
# Image <built-in function dir>: 903_0_1452.jpg
# Image <built-in function dir>: 918_3_687.jpg
# Image <built-in function dir>: 917_3_354.jpg
# Image <built-in function dir>: 902_1_366.jpg
# Image <built-in function dir>: 861_0_1520.jpg
# Image <built-in function dir>: 858_0_1612.jpg
# Image <built-in function dir>: 926_2_760.jpg
# Image <built-in function dir>: 860_2_266.jpg
# Image <built-in function dir>: 886_2_1105.jpg
# Image <built-in function dir>: 922_3_402.jpg
# Image <built-in function dir>: 884_0_539.jpg
# Image <built-in function dir>: 900_3_520.jpg
# Image <built-in function dir>: 843_3_1017.jpg
# Image <built-in function dir>: 935_2_1561.jpg
# Image <built-in function dir>: 920_2_232.jpg
# Image <built-in function dir>: 903_2_1452.jpg
# Image <built-in function dir>: 911_0_1059.jpg
# Image <built-in function dir>: 876_3_751.jpg
# Image <built-in function dir>: 873_0_1557.jpg
# Image <built-in function dir>: 857_3_306.jpg
# ...

# %%
b = os.listdir('//content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/Augmented_Recog/Image')

# %%
len(b)
# Out:
# 4192

# %%
Copy_Lb(labels_train)
# Out:
# Label <built-in function dir>: 859_3_1584.txt
# Label <built-in function dir>: 903_0_1452.txt
# Label <built-in function dir>: 918_3_687.txt
# Label <built-in function dir>: 917_3_354.txt
# Label <built-in function dir>: 902_1_366.txt
# Label <built-in function dir>: 861_0_1520.txt
# Label <built-in function dir>: 858_0_1612.txt
# Label <built-in function dir>: 926_2_760.txt
# Label <built-in function dir>: 860_2_266.txt
# Label <built-in function dir>: 886_2_1105.txt
# Label <built-in function dir>: 922_3_402.txt
# Label <built-in function dir>: 884_0_539.txt
# Label <built-in function dir>: 900_3_520.txt
# Label <built-in function dir>: 843_3_1017.txt
# Label <built-in function dir>: 935_2_1561.txt
# Label <built-in function dir>: 920_2_232.txt
# Label <built-in function dir>: 903_2_1452.txt
# Label <built-in function dir>: 911_0_1059.txt
# Label <built-in function dir>: 876_3_751.txt
# Label <built-in function dir>: 873_0_1557.txt
# Label <built-in function dir>: 857_3_306.txt
# ...

# %%
c = os.listdir('/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/Augmented_Recog/Label')

# %%
len(c)
# Out:
# 4192

# %%
# !unzip '/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_recog.zip' -d '/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_recog/700_2_1026.txt
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_recog/42_1_1172.txt
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_recog/634_2_1705.jpg
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_recog/683_0_1335.jpg
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_recog/513_1_1142.jpg
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_recog/66_1_1420.txt
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_recog/378_0_723.jpg
#   inflating: /content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_recog/265_0_1447.jpg
# ...

# %%
import os
a = os.listdir('/content/drive/MyDrive/CS331_Nhóm/Augmentation_Data/augmented_data_train_detect')

# %%
arr = []
for x in a:
  if x[-4:] == '.txt':
    arr.append(x.split('.')[0])
